# %%
h = "hello"
w = "./nb-simple.ipynb"
n = 5

# %%
from flytekitplugins.papermill.tests.testdata.datatype import X

h = h + " world!"
x = X(x=n)

# %%
from flytekitplugins.notebook  import record_outputs
from flytekit.types.file import PythonNotebook

record_outputs(h=h, w=PythonNotebook(w), x=x)
# Out:
# literals {
#   key: "h"
#   value {
#     scalar {
#       primitive {
#         string_value: "hello world!"
#       }
#     }
#   }
# }
# literals {
#   key: "w"
#   value {
#     scalar {
#       blob {
#         metadata {
#           type {
#             format: "ipynb"
#           }
#         }
#         uri: "/tmp/flyte/20210112_113703/mock_remote/b96d99e5767adf99ea71fa4d6f3374b8/nb-simple.ipynb"
#       }
#     }
#   }
# }
# literals {
#   key: "x"
#   value {
#     scalar {
#       generic {
#         fields {
#           key: "x"
#           value {
#             number_value: 5.0
#           }
#         }
#       }
#     }
#   }
# }
